# %%
# unzip -q ../.autodl/100-bird-species.zip -d ..

# %%
import subprocess
import os
import zipfile

# Function to check if the dataset is downloaded
def is_dataset_downloaded():
    return os.path.isdir("../train")

# Function to check if Kaggle CLI is installed
def is_kaggle_installed():
    try:
        subprocess.run(["kaggle", "--version"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        return True
    except FileNotFoundError:
        return False

# Function to install Kaggle CLI if not already installed
def install_kaggle():
    if not is_kaggle_installed():
        print("Kaggle CLI is not installed. Installing...")
        install_kaggle_command = ["pip", "install", "kaggle"]
        result = subprocess.run(install_kaggle_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        
        if result.returncode == 0:
            print("Kaggle CLI installed successfully")
        else:
            print(f"Kaggle CLI installation failed with return code {result.returncode}")
            return False
    return True

# Function to download and unzip the dataset
def download_and_unzip_dataset():
    # Define the command to download the dataset
    download_command = ["kaggle", "datasets", "download", "-d", "gpiosenka/100-bird-species", "-p", ".."]

    # Run the download command
    result = subprocess.run(download_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if the download was successful
    if result.returncode == 0:
        print("Download executed successfully")

        # Define the path to the downloaded zip file
        zip_file_path = "../100-bird-species.zip"

        # Unzip the downloaded file
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall("..")
        
        print(f"File '{zip_file_path}' has been successfully unzipped.")
    else:
        print(f"Download failed with return code {result.returncode}")

# Download the dataset if not already downloaded
if not is_dataset_downloaded():
    if install_kaggle():
        download_and_unzip_dataset()
else:
    print("Dataset is already downloaded.")
# Out:
# Dataset is already downloaded.

# %%
import os
from PIL import Image
import numpy as np

# dir = '..'
# folds = os.listdir(dir)

# # Delete all empty folders and files that are not .jpg or are not 224x224x3
# for fold in folds:
#     fold_path = os.path.join(dir, fold)
#     if os.path.isdir(fold_path):
#         subfolds = os.listdir(fold_path)
#         for subfold in subfolds:
#             subfold_path = os.path.join(fold_path, subfold)
#             if os.path.isdir(subfold_path):
#                 files = os.listdir(subfold_path)
#                 for file in files:
#                     file_path = os.path.join(subfold_path, file)
#                     if not (file.endswith('.jpg')) or np.array(Image.open(file_path)).shape != (224, 224, 3):
#                         print('Deleting ' + file_path)
#                         os.remove(file_path)

# rename the foldes "PARAKETT  AUKLET" to "PARAKEET AUKLET"
if os.path.exists('../train/PARAKETT  AUKLET'):
    os.rename('../train/PARAKETT  AUKLET', '../train/PARAKETT  AKULET')
    print('renamed train folder')

if os.path.exists('../valid/PARAKETT  AUKLET'):
    os.rename('../valid/PARAKETT  AUKLET', '../valid/PARAKETT  AKULET')
    print('renamed valid folder')

if os.path.exists('../test/PARAKETT  AUKLET'):
    os.rename('../test/PARAKETT  AUKLET', '../test/PARAKETT  AKULET')
    print('renamed test folder')
# Out:
# renamed train folder
# renamed test folder

# %%
import pandas as pd

# Load the CSV file
birds_data = pd.read_csv('../birds.csv')

# Create a dictionary mapping class IDs to class labels
labels_dict = dict(zip(birds_data['labels'], birds_data['class id'].astype(int)))

# Print the dictionary
print(labels_dict)
# Out:
WARBLER': 84, 'BLACK VENTED SHEARWATER': 85, 'BLACK VULTURE': 86, 'BLACK-CAPPED CHICKADEE': 87, 'BLACK-NECKED GREBE': 88, 'BLACK-THROATED SPARROW': 89, 'BLACKBURNIAM WARBLER': 90, 'BLONDE CRESTED WOODPECKER': 91, 'BLOOD PHEASANT': 92, 'BLUE COAU': 93, 'BLUE DACNIS': 94, 'BLUE GRAY GNATCATCHER': 95, 'BLUE GROSBEAK': 96, 'BLUE GROUSE': 97, 'BLUE HERON': 98, 'BLUE MALKOHA': 99, 'BLUE THROATED TOUCANET': 100, 'BOBOLINK': 101, 'BORNEAN BRISTLEHEAD': 102, 'BORNEAN LEAFBIRD': 103, 'BORNEAN PHEASANT': 104, 'BRANDT CORMARANT': 105, 'BREWERS BLACKBIRD': 106, 'BROWN CREPPER': 107, 'BROWN HEADED COWBIRD': 108, 'BROWN NOODY': 109, 'BROWN THRASHER': 110, 'BUFFLEHEAD': 111, 'BULWERS PHEASANT': 112, 'BURCHELLS COURSER': 113, 'BUSH TURKEY': 114, 'CAATINGA CACHOLOTE': 115, 'CABOTS TRAGOPAN': 116, 'CACTUS WREN': 117, 'CALIFORNIA CONDOR': 118, 'CALIFORNIA GULL': 119, 'CALIFORNIA QUAIL': 120, 'CAMPO FLICKER': 121, 'CANARY': 122, 'CANVASBACK': 123, 'CAPE GLOSSY STARLING': 124, 'CAPE LONGCLAW': 125, 'CAPE MAY WARBLER': 126, 'CAPE ROCK THRUSH': 127, 'CAPPED HERON': 128, 'CAPUCHINBIRD': 129, 'CARMINE BEE-EATER': 130, 'CASPIAN TERN': 131, 'CASSOWARY': 132, 'CEDAR WAXWING': 133, 'CERULEAN WARBLER': 134, 'CHARA DE COLLAR': 135, 'CHATTERING LORY': 136, 'CHESTNET BELLIED EUPHONIA': 137, 'CHESTNUT WINGED CUCKOO': 138, 'CHINESE BAMBOO PARTRIDGE': 139, 'CHINESE POND HERON': 140, 'CHIPPING SPARROW': 141, 'CHUCAO TAPACULO': 142, 'CHUKAR PARTRIDGE': 143, 'CINNAMON ATTILA': 144, 'CINNAMON FLYCATCHER': 145, 'CINNAMON TEAL': 146, 'CLARKS GREBE': 147, 'CLARKS NUTCRACKER': 148, 'COCK OF THE  ROCK': 149, 'COCKATOO': 150, 'COLLARED ARACARI': 151, 'COLLARED CRESCENTCHEST': 152, 'COMMON FIRECREST': 153, 'COMMON GRACKLE': 154, 'COMMON HOUSE MARTIN': 155, 'COMMON IORA': 156, 'COMMON LOON': 157, 'COMMON POORWILL': 158, 'COMMON STARLING': 159, 'COPPERSMITH BARBET': 160, 'COPPERY TAILED COUCAL': 161, 'CRAB PLOVER': 162, 'CRANE HAWK': 163, 'CREAM COLORED WOODPECKER': 164, 'CRESTED AUKLET': 165, 'CRESTED CARACARA': 166, 'CRESTED COUA': 167, 'CRESTED FIREB ...
