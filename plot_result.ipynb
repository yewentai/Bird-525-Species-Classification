# %%
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1, 18)
train_accuracy = [0.031084531918168068, 0.2877623736858368, 0.573692798614502, 0.7125685811042786, 0.7831292748451233, 0.8276522159576416, 0.8604623675346375, 0.8813705444335938, 0.8956954479217529, 0.9080819487571716, 0.9162135720252991, 0.9231869578361511, 0.9293447136878967, 0.9369326829910278, 0.9409512281417847, 0.9446742534637451, 0.9479999542236328]

# Create a figure with a transparent background
figure = plt.figure(figsize=(5, 5), facecolor='none')

plt.plot(epochs, train_accuracy, label='Train')

ax = plt.gca()
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)
ax.spines['top'].set_linewidth(1)
ax.spines['right'].set_linewidth(1)

plt.title('Training Accuracy (ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Save the figure with a transparent background
figure.savefig('./figures/train_accuracy.png', dpi=300, transparent=True)
plt.show()

# %%
epochs = np.arange(1, 18)
cross_entropy_loss = [6.120931148529053, 4.825237274169922, 3.5727977752685547, 2.9912068843841553, 2.7387804985046387, 2.512110948562622, 2.426212787628174, 2.3732409477233887, 2.3066115379333496, 2.2691650390625, 2.246136426925659, 2.2215774059295654, 2.1952476501464844, 2.20322585105896, 2.2215774059295654, 2.2215774059295654, 2.2215774059295654]

figure = plt.figure(figsize=(5, 5), facecolor='none')
plt.plot(epochs, cross_entropy_loss, label='Train')

ax = plt.gca()
ax.spines['top'].set_color('black')
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)
ax.spines['top'].set_linewidth(1)
ax.spines['right'].set_linewidth(1)

plt.title('Training Loss (ResNet50)')
plt.xlabel('Epochs')
plt.ylabel('Cross Entropy Loss')
plt.legend()
plt.show()
figure.savefig('./figures/train_loss.png', dpi=300, transparent=True)
